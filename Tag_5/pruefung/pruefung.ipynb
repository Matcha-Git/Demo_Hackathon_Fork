-- %% [markdown]
-- # **Aufgabe 1**

-- %%
RESTORE DATABASE soundlib
FROM DISK = N'C:\m106_projekt\soundlib.bak'
-- Out:
-- : Msg 3169, Level 16, State 1, Line 1
-- Die Datenbank wurde auf einem Server der Version 16.00.1050 gesichert. Diese Version ist mit diesem Server inkompatibel, da auf ihm die Version 15.00.2130 ausgeführt wird. Stellen Sie die Datenbank auf einem Server wieder her, der die Sicherung unterstützt, oder verwenden Sie eine mit diesem Server kompatible Sicherung.
-- : Msg 3013, Level 16, State 1, Line 1
-- RESTORE DATABASE wird fehlerbedingt beendet.
-- Total execution time: 00:00:00.030

-- %% [markdown]
-- # **Aufgabe 2**

-- %%
SELECT 'Ich,Quentin Lorenzo, habe am 28.06.2008 Geburtstag!' AS 'About Me';
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.002
-- <table><tr><th>About Me</th></tr><tr><td>Ich,Quentin Lorenzo, habe am 28.06.2008 Geburtstag!</td></tr></table>

-- %% [markdown]
-- # **Aufgabe 3**

-- %%
USE soundlib;
GO

INSERT INTO Employee (LastName,FirstName) 
VALUES ('Lorenzo', 'Quentin');
-- Out:
-- Commands completed successfully.
-- (1 row affected)
-- Total execution time: 00:00:00.017

-- %%
SELECT * FROM Employee WHERE LastName = 'Lorenzo';
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.021
-- <table><tr><th>EmployeeId</th><th>LastName</th><th>FirstName</th><th>Title</th><th>ReportsTo</th><th>BirthDate</th><th>HireDate</th><th>Address</th><th>City</th><th>State</th><th>Country</th><th>PostalCode</th><th>Phone</th><th>Fax</th><th>Email</th></tr><tr><td>9</td><td>Lorenzo</td><td>Quentin</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td></tr></table>

-- %% [markdown]
-- # **Aufgabe 4**

-- %%
USE master;
CREATE LOGIN quentin
WITH PASSWORD = '123ict', CHECK_POLICY = OFF;

USE soundlib;
CREATE USER quentin FOR LOGIN quentin;
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.019

-- %%
GRANT SELECT, INSERT, UPDATE, DELETE ON Artist TO quentin;
GRANT SELECT, INSERT, UPDATE, DELETE ON Album TO quentin;
GRANT SELECT ON InvoiceLine TO quentin;
GRANT SELECT ON Invoice TO quentin;
GRANT SELECT, INSERT, UPDATE, DELETE ON PlaylistTrack TO quentin;
GRANT SELECT, INSERT, UPDATE, DELETE ON Track TO quentin;
GRANT SELECT ON Customer TO quentin;
GRANT SELECT, INSERT, UPDATE, DELETE ON Playlist TO quentin;
GRANT SELECT, INSERT, UPDATE, DELETE ON Genre TO quentin;
GRANT SELECT, INSERT, UPDATE, DELETE ON MediaType TO quentin;
GRANT SELECT ON Employee TO quentin;
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.024

-- %% [markdown]
-- # **Aufgabe 5**

-- %%
-- i
SELECT COUNT(TrackId) FROM PlaylistTrack;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.009
-- <table><tr><th>(No column name)</th></tr><tr><td>8715</td></tr></table>

-- %% [markdown]
-- # **Aufgabe 6**

-- %%
SELECT * FROM Customer WHERE FirstName LIKE '%q';
-- Out:
-- (0 rows affected)
-- Total execution time: 00:00:00.020
-- <table><tr><th>CustomerId</th><th>FirstName</th><th>LastName</th><th>Company</th><th>Address</th><th>City</th><th>State</th><th>Country</th><th>PostalCode</th><th>Phone</th><th>Fax</th><th>Email</th><th>SupportRepId</th></tr></table>

-- %% [markdown]
-- # **Aufgabe 7**

-- %%
SELECT MAX(TrackId) AS 'Anzahl Songs' FROM Track;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.007
-- <table><tr><th>Anzahl Songs</th></tr><tr><td>3503</td></tr></table>

-- %% [markdown]
-- # **Aufgabe 8**

-- %% [markdown]
-- # **Aufgabe 9**

-- %% [markdown]
-- # **Aufgabe 10**

-- %% [markdown]
-- # **Aufgabe 11**

-- %%
SELECT DISTINCT UnitPrice FROM Track ORDER BY UnitPrice ASC;
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:00.021
-- <table><tr><th>UnitPrice</th></tr><tr><td>0.99</td></tr><tr><td>1.99</td></tr></table>

-- %% [markdown]
-- # **Aufgabe 12**

-- %%
SELECT Name, Milliseconds FROM Track ORDER BY Milliseconds DESC;
-- Out:
-- (3503 rows affected)
-- Total execution time: 00:00:00.040
-- ...

-- %% [markdown]
-- # **Aufgabe 13**

-- %%
ALTER TABLE Playlist ADD CreationDate datetime DEFAULT(GETDATE());
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.007

-- %% [markdown]
-- # **Aufgabe 14**

-- %% [markdown]
-- # **Aufgabe 15**

-- %%
ALTER TABLE InvoiceLine
ADD CONSTRAINT CK_price CHECK(UnitPrice >= 0);
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.035

-- %% [markdown]
-- # **Aufgabe 16**

-- %% [markdown]
-- # **Aufgabe 17**

-- %%
SELECT HireDate FROM Employee;
-- Out:
-- (9 rows affected)
-- Total execution time: 00:00:00.002
-- <table><tr><th>HireDate</th></tr><tr><td>2002-08-14 00:00:00.000</td></tr><tr><td>2002-05-01 00:00:00.000</td></tr><tr><td>2002-04-01 00:00:00.000</td></tr><tr><td>2003-05-03 00:00:00.000</td></tr><tr><td>2003-10-17 00:00:00.000</td></tr><tr><td>2003-10-17 00:00:00.000</td></tr><tr><td>2004-01-02 00:00:00.000</td></tr><tr><td>2004-03-04 00:00:00.000</td></tr><tr><td>NULL</td></tr></table>

-- %%
SELECT FirstName, LastName, City FROM Employee WHERE HireDate > 2008-06-28;
-- Out:
-- (8 rows affected)
-- Total execution time: 00:00:00.009
-- <table><tr><th>FirstName</th><th>LastName</th><th>City</th></tr><tr><td>Andrew</td><td>Adams</td><td>Edmonton</td></tr><tr><td>Nancy</td><td>Edwards</td><td>Calgary</td></tr><tr><td>Jane</td><td>Peacock</td><td>Calgary</td></tr><tr><td>Margaret</td><td>Park</td><td>Calgary</td></tr><tr><td>Steve</td><td>Johnson</td><td>Calgary</td></tr><tr><td>Michael</td><td>Mitchell</td><td>Calgary</td></tr><tr><td>Robert</td><td>King</td><td>Lethbridge</td></tr><tr><td>Laura</td><td>Callahan</td><td>Lethbridge</td></tr></table>

-- %% [markdown]
-- # **Aufgabe 18**

-- %%
ALTER TABLE Customer
ADD PrivateCustomer BIT;

INSERT INTO Customer (PrivateCustomer)
VALUES
-- Out:
-- (59 rows affected)
-- Total execution time: 00:00:00.008
-- ...

-- %% [markdown]
-- # **Aufgabe 19**

-- %%
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.002
-- <table><tr><th>(No column name)</th></tr><tr><td>2025-01-16 15:43:35.767</td></tr></table>

-- %% [markdown]
-- # **Aufgabe 20**

-- %%
BEGIN TRANSACTION

BEGIN TRY
    UPDATE Employee SET Title = 'Sales Support Agent' WHERE EmployeeId = 7;
    UPDATE Customer SET SupportRepId = 7 WHERE SupportRepId = 5;
    DELETE FROM Employee WHERE EmployeeId = 5;


    COMMIT TRANSACTION
END TRY

BEGIN CATCH
    ROLLBACK TRANSACTION
END CATCH

GO
-- Out:
-- (1 row affected)
-- (18 rows affected)
-- (1 row affected)
-- Total execution time: 00:00:00.065

-- %%
SELECT * FROM Employee WHERE EmployeeId = 5;
SELECT * FROM Employee WHERE EmployeeId = 7;
SELECT SupportRepId FROM Customer;
-- Out:
-- (0 rows affected)
-- (1 row affected)
-- (59 rows affected)
-- Total execution time: 00:00:00.011
-- <table><tr><th>EmployeeId</th><th>LastName</th><th>FirstName</th><th>Title</th><th>ReportsTo</th><th>BirthDate</th><th>HireDate</th><th>Address</th><th>City</th><th>State</th><th>Country</th><th>PostalCode</th><th>Phone</th><th>Fax</th><th>Email</th></tr></table>
-- <table><tr><th>EmployeeId</th><th>LastName</th><th>FirstName</th><th>Title</th><th>ReportsTo</th><th>BirthDate</th><th>HireDate</th><th>Address</th><th>City</th><th>State</th><th>Country</th><th>PostalCode</th><th>Phone</th><th>Fax</th><th>Email</th></tr><tr><td>7</td><td>King</td><td>Robert</td><td>Sales Support Agent</td><td>6</td><td>1970-05-29 00:00:00.000</td><td>2004-01-02 00:00:00.000</td><td>590 Columbia Boulevard West</td><td>Lethbridge</td><td>AB</td><td>Canada</td><td>T1K 5N8</td><td>+1 (403) 456-9986</td><td>+1 (403) 456-8485</td><td>robert@soundlibcorp.com</td></tr></table>
-- ...

-- %% [markdown]
-- # **Aufgabe 21**

-- %%
SELECT Name FROM Artist
INTERSECT
SELECT Composer from Track;
-- Out:
-- (47 rows affected)
-- Total execution time: 00:00:00.005
-- ...

-- %% [markdown]
-- # **Aufgabe 22**

-- %% [markdown]
-- # **Aufgabe 23**

-- %% [markdown]
-- # **Aufgabe 24**

-- %%
SELECT SUM(Total) AS 'Total aller Rechnungen' FROM Invoice GROUP BY CustomerId;
-- Out:
-- (58 rows affected)
-- Total execution time: 00:00:00.015
-- ...

-- %% [markdown]
-- # **Aufgabe 25**

-- %% [markdown]
-- # **Aufgabe 26**

-- %%
BACKUP DATABASE soundlib
TO DISK = N'C:\m106_projekt\soundlib_backup.bak' 
WITH NOFORMAT, NOINIT, NAME = N'Soundlib vollständige Datenbanksicherung', SKIP, STATS = 10
GO
-- Out:
-- 10 Prozent verarbeitet.
-- 20 Prozent verarbeitet.
-- 30 Prozent verarbeitet.
-- 40 Prozent verarbeitet.
-- 50 Prozent verarbeitet.
-- 60 Prozent verarbeitet.
-- 70 Prozent verarbeitet.
-- 80 Prozent verarbeitet.
-- 90 Prozent verarbeitet.
-- 100 Prozent verarbeitet.
-- 976 Seiten wurden für die soundlib-Datenbank, Datei "soundlib" für Datei 1, verarbeitet.
-- 2 Seiten wurden für die soundlib-Datenbank, Datei "soundlib_log" für Datei 1, verarbeitet.
-- BACKUP DATABASE hat erfolgreich 978 Seiten in 0.051 Sekunden verarbeitet (149.739 MB/s).
-- Total execution time: 00:00:00.122
